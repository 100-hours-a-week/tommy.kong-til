# %% [markdown]
# MNIST 데이터셋을 이용해 ResNet 모델을 훈련하고 평가해 보세요.
#
# ### 문제 설명
#
# 1. 라이브러리 임포트
#     - 필요한 라이브러리를 임포트합니다.
# 2. 데이터셋 로드 및 전처리
#     - MNIST 데이터셋을 로드하고, 데이터를 전처리합니다.
#         ```python
#         # 2. 데이터셋 로드 및 전처리
#         (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
#         x_train = x_train.astype('float32') / 255.0
#         x_test = x_test.astype('float32') / 255.0
#
#         x_train = np.stack([x_train]*3, axis=-1)
#         x_test = np.stack([x_test]*3, axis=-1)
#
#         y_train = to_categorical(y_train, 10)
#         y_test = to_categorical(y_test, 10)
#         ```
# 3. 모델 생성
#     - ResNet 모델을 생성하고 필요한 레이어를 추가합니다.
# 4. 모델 컴파일
#     - 옵티마이저와 손실 함수를 설정하여 모델을 컴파일합니다.
# 5. 모델 훈련
#     - 훈련 데이터를 사용하여 모델을 훈련합니다.
# 6. 모델 평가
#     - 테스트 데이터를 사용하여 모델의 성능을 평가합니다.

# %% [markdown]
# ---

# %% [markdown]
# CIFAR-10 데이터셋을 이용해 ResNet 모델을 훈련하고 평가해 보세요.
#
# ### 문제 설명
#
# 1. 라이브러리 임포트
#     - 필요한 라이브러리를 임포트합니다.
# 2. 데이터셋 로드 및 전처리
#     - CIFAR-10 데이터셋을 로드하고, 데이터를 전처리합니다.
#
#         ```python
#         # 2. 데이터셋 로드 및 전처리
#         (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#
#         x_train = x_train.astype('float32') / 255.0
#         x_test = x_test.astype('float32') / 255.0
#
#         y_train = to_categorical(y_train, 10)
#         y_test = to_categorical(y_test, 10)
#         ```
#
# 3. 모델 생성
#     - ResNet 모델을 생성하고 필요한 레이어를 추가합니다.
# 4. 모델 컴파일
#     - 옵티마이저와 손실 함수를 설정하여 모델을 컴파일합니다.
# 5. 모델 훈련
#     - 훈련 데이터를 사용하여 모델을 훈련합니다.
# 6. 모델 평가
#     - 테스트 데이터를 사용하여 모델의 성능을 평가합니다.

# %% [markdown]
# ---

# %% [markdown]
# MNIST 데이터셋을 이용한 VGG16 모델을 훈련한 뒤 평가해 보세요.
#
# ### 문제 설명
#
# 1. 라이브러리 임포트
#     - 필요한 라이브러리를 임포트합니다.
# 2. 데이터셋 로드 및 전처리
#     - MNIST 데이터셋을 로드하고, 데이터를 전처리합니다.
#
#         ```python
#         python코드 복사
#         # 2. 데이터셋 로드 및 전처리
#         (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
#         x_train = x_train.astype('float32') / 255.0
#         x_test = x_test.astype('float32') / 255.0
#
#         x_train = np.stack([x_train]*3, axis=-1)
#         x_test = np.stack([x_test]*3, axis=-1)
#
#         y_train = to_categorical(y_train, 10)
#         y_test = to_categorical(y_test, 10)
#         ```
#
# 3. 모델 생성
#     - VGG16 모델을 생성하고 필요한 레이어를 추가합니다.
# 4. 모델 컴파일
#     - 옵티마이저와 손실 함수를 설정하여 모델을 컴파일합니다.
# 5. 모델 훈련
#     - 훈련 데이터를 사용하여 모델을 훈련합니다.
# 6. 모델 평가
#     - 테스트 데이터를 사용하여 모델의 성능을 평가합니다.

# %% [markdown]
# ---

# %% [markdown]
# CIFAR-10 데이터셋을 이용한 VGG16 모델을 훈련한 뒤 평가해 보세요.
#
# ### 문제 설명
#
# 1. 라이브러리 임포트
#     - 필요한 라이브러리를 임포트합니다.
# 2. 데이터셋 로드 및 전처리
#     - CIFAR-10 데이터셋을 로드하고, 데이터를 전처리합니다.
#
#         ```python
#         # 2. 데이터셋 로드 및 전처리
#         (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#
#         x_train = x_train.astype('float32') / 255.0
#         x_test = x_test.astype('float32') / 255.0
#
#         y_train = to_categorical(y_train, 10)
#         y_test = to_categorical(y_test, 10)
#         ```
#
# 3. 모델 생성
#     - VGG16 모델을 생성하고 필요한 레이어를 추가합니다.
# 4. 모델 컴파일
#     - 옵티마이저와 손실 함수를 설정하여 모델을 컴파일합니다.
# 5. 모델 훈련
#     - 훈련 데이터를 사용하여 모델을 훈련합니다.
# 6. 모델 평가
#     - 테스트 데이터를 사용하여 모델의 성능을 평가합니다.

# %% [markdown]
# ---

# %% [markdown]
# ResNet50을 **Feature Extractor**로 활용하여 **MNIST 손글씨 데이터셋**을 분류하는 모델을 구현하세요.
#
# ResNet50의 사전 학습된 가중치를 활용하고, Fully Connected Layer(FC Layer)를 새롭게 추가하여 MNIST 데이터셋을 학습 및 평가합니다.
#
# ### **문제 설명**
#
# 1. **ResNet50 모델을 Feature Extractor로 설정**
#     - 사전 학습된 **ImageNet 가중치**를 로드하고, 기존의 FC Layer를 제거하세요.
#     - ResNet50의 모든 가중치를 **고정**하여 학습되지 않도록 설정하세요.
# 2. **새로운 Fully Connected Layer 추가**
# 3. **MNIST 데이터셋 로드 및 전처리**
#     - MNIST 데이터를 불러오고, **RGB 3채널로 변환 후, 크기를 (32, 32)로 조정**하세요.
#     - 데이터 값을 **정규화 (0~1 범위로 변환)** 하세요.
#     - **훈련 데이터(Train)와 테스트 데이터(Test)로 분할**하세요.
# 4. **모델 학습 및 평가**
#     - 모델의 **테스트 정확도를 출력**하세요.
# 5. **임의의 테스트 샘플 예측**
#     - 테스트 데이터 중 **하나를 선택하여 예측 수행**하세요.
#     - 예측된 **클래스(숫자)** 를 출력하세요.

# %% [markdown]
# ---

# %% [markdown]
# VGG16을 Feature Extractor로 활용하여 CIFAR-10 데이터셋을 분류하는 모델을 구현하세요.
#
# VGG16의 사전 학습된 가중치를 활용하고, Fully Connected Layer(FC Layer)를 새롭게 추가하여 CIFAR-10 데이터셋을 학습 및 평가합니다.
#
# ### 문제 설명
#
# 1. VGG16 모델을 Feature Extractor로 설정
#     - 사전 학습된 ImageNet 가중치를 로드하고, 기존의 FC Layer를 제거하세요.
#     - VGG16의 모든 가중치를 고정하여 학습되지 않도록 설정하세요.
# 2. 새로운 Fully Connected Layer 추가
# 3. CIFAR-10 데이터셋 로드 및 전처리
#     - CIFAR-10 데이터를 불러오고, 입력 이미지를 (32, 32, 3) 크기로 유지하세요.
#     - 데이터 값을 정규화 (0~1 범위로 변환) 하세요.
#     - 라벨(Label)을 One-Hot Encoding으로 변환하세요.
#     - 훈련 데이터(Train)와 테스트 데이터(Test)로 분할하세요.
# 4. 모델 학습 및 평가
#     - 학습이 완료되면, 테스트 데이터에서 모델의 정확도(Test Accuracy)를 출력하세요.
# 5. 임의의 테스트 샘플 예측
#     - 테스트 데이터 중 5개를 선택하여 예측 수행하세요.
#     - 예측된 클래스(라벨) 및 실제 정답을 출력하세요.

# %% [markdown]
# ---

# %% [markdown]
# ResNet50과 MNIST 데이터셋을 활용하여 숫자 0~4만 학습하고, 학습되지 않은 숫자 5~9를 Zero-Shot Learning 방식으로 예측하는 모델을 구현하세요.
#
# ### **문제 설명 (예시)**
#
# 1. **MNIST 데이터셋 로드 및 전처리**
#     - 학습 데이터는 **숫자 0~4만 포함**
#     - 테스트 데이터는 **숫자 5~9만 포함 (Zero-Shot 데이터)**
#     - ResNet50을 **Feature Extractor**로 사용하여 이미지 특징을 추출
# 2. **0~4 숫자만 학습하는 분류 모델 구현**
#     - ResNet50의 Fully Connected Layer를 제거하고 **Feature Extractor**로 활용
#     - Feature Extractor에서 얻은 벡터를 입력으로 받아 **0~4를 예측하는 분류 모델 학습**
# 3. **Zero-Shot 방식으로 5~9 숫자를 예측**
#     - 학습된 0~4 숫자의 **평균 Feature Vector(클래스 중심)를 계산**
#     - 새로운 숫자(59)의 Feature Vector를 추출하고, 각 클래스(04)의 평균 벡터와의 거리를 비교하여 가장 가까운 클래스로 분류
#     - 분류 결과를 출력하고, **각 샘플의 최근접 클래스 거리도 출력**

# %% [markdown]
# ---

# %% [markdown]
# MNIST 데이터셋을 직접 학습한 기본 CNN 모델과 Fine Tuning을 진행한 ResNet50 모델하고 비교해 보세요.
#
# Fine Tuning 방법은 어떤 것을 적용해도 상관 없습니다.
#
# ### 문제 설명
#
# 1. 라이브러리 임포트
# 2. 데이터셋 로드 및 전처리
#
#     ```python
#     # 2. MNIST 데이터셋 로드 및 전처리
#     (x_train, y_train), (x_test, y_test) = mnist.load_data()
#     x_train = np.expand_dims(x_train, -1)
#     x_test = np.expand_dims(x_test, -1)
#     x_train = np.repeat(x_train, 3, axis=-1)  # 채널을 3으로 확장
#     x_test = np.repeat(x_test, 3, axis=-1)
#     x_train = x_train.astype('float32') / 255.0
#     x_test = x_test.astype('float32') / 255.0
#     y_train = to_categorical(y_train, 10)
#     y_test = to_categorical(y_test, 10)
#
#     # 데이터셋 분할 (훈련:검증 = 8:2)
#     x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
#     ```
#
# 3. 기본 CNN 모델 정의 및 훈련
# 4. ResNet50 모델 정의 및 파인튜닝
# 5. 두 모델의 성능 비교

# %% [markdown]
# ---

# %% [markdown]
# MNIST 데이터셋을 ResNet50, VGG16 에 Fine Tuning하고 모델 두 개를 비교해 보세요.
#
# Fine Tuning 방법은 어떤 것을 적용해도 상관 없습니다.
#
# ### 문제 설명
#
# 1. 라이브러리 임포트
# 2. 데이터셋 로드 및 전철
#
#     ```python
#     # 데이터셋 로드 및 전처리
#     transform = transforms.Compose([
#         transforms.Resize((224, 224)),
#         transforms.Grayscale(num_output_channels=3),  # 흑백 이미지를 3채널로 변환
#         transforms.ToTensor(),
#         transforms.Normalize((0.5,), (0.5,))
#     ])
#
#     train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
#     test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
#
#     train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
#     test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
#     ```
#
# 3. VGG16 모델 구성 및 학습
# 4. ResNet50 모델 구성 및 학습
# 5. 모델 평가

# %% [markdown]
# ---
